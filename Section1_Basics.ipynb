# %% [markdown]
# Basic Variables Output

# %%
name = 'Anas'
reg = '58'
uni = 'Nutech'

print(f'My Name is {name}, I study in {uni} University and my registration number is {reg}.')
# Out:
# My Name is Anas, I study in Nutech University and my registration number is F24607058.

# %% [markdown]
# User Input

# %%
name = input('Whats Your Name, brother?')
uni = input('In which University You Study?')
reg = input('Whats Your Registration Number?')

print(f'OK, So Just a quick recap, Your name is {name}, You study in {uni} University having Registration Number {reg}. Cool?')
# Out:
# OK, So Just a quick recap, Your name is Anas, You study in Nutech  University having Registration Number 58. Cool?

# %% [markdown]
# Data Types Sort of thing

# %%
name = input("Enter Your Name: ")
age = int(input("Enter Your Age: "))
height = float(input("Enter Your Height: "))

print("===== Student Report =====")
print("Name: ", name)
print("Age: ", age)
print("Height: ", height)
print()
print(f"You Gonna be {age+1} next year")
print()
print(type(name))
print(type(age))
print(type(height))
# Out:
# ===== Student Report =====
# Name:  Anas
# Age:  20
# Height:  175.0
#
# You Gonna be 21 next year
#
# <class 'str'>
# <class 'int'>
# <class 'float'>
